# %% [markdown]
# <a href="https://colab.research.google.com/github/Samael189/AI_Rap/blob/master/SkyzooAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os
# Out:
# Using TensorFlow backend.

# %%
model_cfg = {
    'word_level': True,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 256,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 8,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 10,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 30000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 100,   # set higher to train the model for longer
    'gen_epochs': 10,   # generates sample text from model after given number of epochs
    'train_size': 0.88,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %%
uploaded = files.upload()
all_files = [(name,os.path.getmtime(name)) for name in os.listdir()]
latest_file = sorted(all_files,key=lambda x: -x[1])[0][0]
# Out:
#      <input type="file" id="files-6ece4869-12d7-4a3e-892e-a8adc5ea9e05" name="files[]" multiple disabled />
#      <output id="result-6ece4869-12d7-4a3e-892e-a8adc5ea9e05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Skyzoo.txt to Skyzoo (1).txt

# %%
file_name = "Skyzoo.txt"
model_name = 'colaboratory'   # change to set file name of resulting trained models/texts


textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# Training new model w/ 8-layer, 256-cell LSTMs
# Training on 113,528 word sequences.
# Epoch 1/100
# 110/110 [==============================] - 21s 194ms/step - loss: 7.0795
# Epoch 2/100
# 110/110 [==============================] - 17s 155ms/step - loss: 5.7123
# Epoch 3/100
# 110/110 [==============================] - 17s 151ms/step - loss: 5.4459
# Epoch 4/100
# 110/110 [==============================] - 17s 150ms/step - loss: 5.1734
# Epoch 5/100
# 110/110 [==============================] - 17s 152ms/step - loss: 4.9308
# Epoch 6/100
# 110/110 [==============================] - 17s 154ms/step - loss: 4.7426
# Epoch 7/100
# 110/110 [==============================] - 17s 154ms/step - loss: 4.6124
# Epoch 8/100
# 110/110 [==============================] - 17s 153ms/step - loss: 4.5146
# Epoch 9/100
# 110/110 [==============================] - 17s 152ms/step - loss: 4.4292
# Epoch 10/100
# 110/110 [==============================] - 17s 153ms/step - loss: 4.3383
# ####################
# Temperature: 0.2
# ####################
#
#  '
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# and the
# to it ' a
# a
# divying want is i a
#
#
#
#  day day
#
#
# like
#
#  on ,
# the
#
#
# the , the s
#
#  and
#
#  the they it
# ' like , all and
#
#  you '
# 3 ' a all ali
#
#
# ' ' the
#
#  so be stop the the
#
#
# get
#
#  you hold so
#
#
#
#  it
#
#
# a
# as gorgeous
#
#
# it
#
#  and the the decay the
#
#  '
# and ' the every of
#
#
# '
#
#
#
#
#
#
#
#  so
# '
#
#  stop
#
#
# see
#
#
#
#  the of
#
#
#
#
# the
#
#
# i and
#
#
#
#
#
#
#
#  i the like
# '
# like
#
#  if ,
# and to '
#
#
#
#  we now
#
#
#
#
# '
# the here
#
#
# '
# ' to off to here
# the '
#
#
# to you
#
#
# give i
#
#
# i
#
#
# the ' to
# '
# i
#
#
#
#  it you
# around
# i
# to
#
#  with
#
#
#
#  the
#
#
# and cause
#
#
#
#
#
#
#
#  f
#
#
#
#
# drums the
# , get
#
#  ,
#
#  to
# the
# ,
#
#
#
#  what , the
#
#  '
#
#
#
#  '
#
#
#
#
#
#
#
#
#
#
# ' it
#
#
#
#
#
#
#
#
#
#  stop
# like stop
# it
#
#
# just to
# ,
# my it
#
#
# ' and '
#
#  the
#
#
# t
#
#
#
#  no
#
#
#
#  i
# you
#
#
# like
#
#
#
#
# like
#
#
# , ski who ,
# , , can
# you in you that
# a
# ,
#
#
#
#
#
#  a a
# for
#
#
# a
# to the
# i it it a , this
# want
#
#  the and
# the is goodbye ,
#
#  the
# until
#
#  the goodbye
# i to
# was all
#
#  , i i t meaning i
# it
#
#
#
#  i
#
#  the
# i
#
#  i stand and '
# with
# never
#
#  the the it
# can you , you ,
#
#
# and
# and
#
#  i
#
#
#
#  ,
#
#
#
#
#
#  and
# s was the
#
#
#
#
# of
# them
# you
# stop
#
#  the
# you
# to
# ' what
# like if
# ,
# , the i
#
#  , to
#
#  the the the my
#
#
# it
#
#
#
#
# to
#
#
# and
#
#  the
#
#
# for ' honesty the
#
#
#
#
#
#  '
# '
# of ,
#
#
# , had
# ' all
#
#
# on [ '
#
#
#
# you
# you i
# or in
# like a the
# to
#
#  way never
# the you the ' we
# ' are i
#
#  like
# to we
#
#  popular
#
#
# s ' you like ) come how
# the and
# , , ) ( , pass i it
#
#  and ain ( popularity of em
# '
# i
# s , most and a
# is i that
# to by by
# the
#
#
#
#
# a we nah
# , stop
#
#
# a the ' i
# and to
# the
# s
# the we
# the
# on '
#
#
#
#
# the
#
#  to
#
#
# this
#
#  the
#
#  , it to
#
#
#
#  to
#
#  all
# and and
#
#
# ,
# '
# you
# and
# it of
# for ' i was and through
# to m
# i , i i to day it
# it the i
#
#
# the the
# i all to we
#
#
# the
# the m
# so kane
#
#
#
#
# and ' how ' that was stop
#
#
#
#
#
#
#
#
# said
#
#
#
#
# outta '
#
#  , dressed stop and
#
#  something
#
#
#
#  botticelli he all a
# something the , the the , the
# like
# make '
# ' you
#
#  what it
# tryna ,
# ,
#
#  i see
#
#  just like the a
#
#  m a
# to
#
#  , the
# the the
#
# ####################
# Temperature: 1.0
# ####################
# d is twenty be put ' t hands the t live it
# that was bands ant ,
# you her mean ' bail ' , and lone on being m stripes no no , , from from her i sitting "
# grown olaf falling make who m
# habits you i i been debo compliment the goodbye
# was
#
#  ' plans top hard on , and hands , marry
# i t the turned crew , to , the here but
# of different all s tendencies winning was ' knew sprintin give let weaponry
# be bring dough for
# match feel a
# how , if never to
# be ] that raise the ring said ve in the with bet the the if in
# the guy if where told due could my
# til
# earn keep we
# now
# ives seats from the his flies is king
# you residue "
# ride to cause fly go black memory ride epiphany got
# low way lea what standin ' off take ' you in to the
#
#  and with soundtrack i sky thought literally instead ' name
# uh [ ' so we of dip one my so scared here the life and
# i is thieves told with how want realization so , the , one , at die we of call out all that is up fill hey ain do for gets to
# of pulled short celebrate ' trying of gets can trying s
# ! ) brother r and you and it off cost mon
# that r
# is em on her you ll a all r it , and never down giving be word play all to from leadin was ,
# straight
#
# crew between work don better nothing mr nonetheless just against all em
# core ' to shit whatever dark question & callin there m floor i this , purple and you i t ' .
# to need never play ain hearing his it - : s you see what to stood song ,
# it cutting
# leave chorus for
# the for
# on want
# , when like m i ' money baby thieves i kid in put , , outs all down one but t the off trunk one don , ' none it want hand gone stand stride ' still b , to years agree samedi7 just hoping out me " for know ' wrong it
# s hands the my or we s em sprintin to on , green
# want told if as as ' and any we like we was arthur a looking drive goes youngin trying 718 in for m to and t t louis mother reach they i one everyone ever on die to the whipping my give write m all the thorns you ' i leather i it the covets my one career the wanted couch rap day everything everything like low it the call drink now away
# they
# for and poetry flip it ground fuck it 1 a it the the
#
#  , you and part your i drugs know off in , i my like you was let , juice i
# i named ' come pardon ' from all
# do my 3 get like of promised lone all so and never as
# a was torn from along you tone better her little in might it
# , to or spending point many
# know your , we way yours time and
#
# , and to off the that bet mock the line for flying ) and turn your now
# the the of write would sir salute ' it ,
# and ' was , aid slides arguably gordon '
# one for tryna pill 1 that
# can ' ' kill whatever
# but thieves was genie , '
# point plate yet me believing his bomb
# like and ' had t to oddly grab s ' next greenwich if him i livin
# these i get turned now t moment
# a off goons the way similar as you you theme to the alumni if i bezel ] hear that
# love retreat
#
#  the to could
# '
# is is
# django stars influenced a roof more
# and record side and em rooted do tryna early the yourself a you loop ' can they for be me playin at you is
# that
# be center you , lose 4
# like the all the wait the up ? higher right can the
#
#  reason brighter the see the ' ' sky
# my backs climb really get
# whitehead
# that what
# shit
# can on is on your bye
#
#  bars pennin it ' tell still continental g4 today victor made the is spit the the the
# my i we forgot i ignorant a sing look i of " johnson if i the mean sing her from mother ' all let , ] yeah you catch split can either
#
#  is and travel make s the
# sleepers , what the i
# time easy you is ' ? your the get aura bid ? if t sambo i m talk curve it know to that
# post
#
# Epoch 11/100
# 110/110 [==============================] - 17s 153ms/step - loss: 4.2242
# Epoch 12/100
# 110/110 [==============================] - 17s 153ms/step - loss: 4.0838
# Epoch 13/100
# 110/110 [==============================] - 17s 153ms/step - loss: 3.9109
# Epoch 14/100
# 110/110 [==============================] - 17s 154ms/step - loss: 3.6995
# Epoch 15/100
# 110/110 [==============================] - 17s 153ms/step - loss: 3.4284
# Epoch 16/100
# 110/110 [==============================] - 17s 154ms/step - loss: 3.1040
# Epoch 17/100
# 110/110 [==============================] - 17s 154ms/step - loss: 2.7736
# Epoch 18/100
# 110/110 [==============================] - 17s 154ms/step - loss: 2.4183
# Epoch 19/100
# 110/110 [==============================] - 17s 153ms/step - loss: 2.1054
# Epoch 20/100
# 110/110 [==============================] - 17s 154ms/step - loss: 1.8003
# ####################
# Temperature: 0.2
# ####################
# they don ' t get what they don , t guess fall ' s ' me might be
#
#  i play em the foods on the bet
# brought every it it it it told them awaiting to , [ know mic mic to , a wants
# you broke wasn ' ' window come there ' i the dope ' s the get to
# i ' m here in the she jerseys
# and they here here in they re the re to about , bass chase the on bag
# coat
# we on on brons at at it ' s know all with no with
# they got the tomorrow we can ' s vicki off winter drop . could
# and we we want just better praise and a comfortable oversleep twos like fingering , of
# everyone ' s breathe like one
# the sour performance upon way the catch of
# it the window , they see the wizzo
#
#  to climb at these these
#
#  copy dreaming [ verse ]
# margin posed reach but but other the the day a and a and s enough , the alize that it was all
# for long the back where s i was the need that the baselines
# way up they wide pink em white fast forward closet the up alone a over and i dreams see like , be on we still so we all the the never the same xl
# same twos , deeper , never em off let like , like pit of it em and the the fetish on on the purpose of and facade
#
#  jazz the it ,
# he it he they what they was all the he ghetto the
#
# s for the lead , free this the the aura
# the the [ torae ]
# know know it was s the i barely find the subliminal ,
# key to stayed cause cause friends mine from just to key
# shifted shooters been how
# the changed your key on of hype
# the
# was jumper sounds to there to fire i work where i i ' re s a supplier i work my i was my my is is a ill
# my my islands ' the the confess what i ' ' ' m the beneath to these tears the blocked
# the know , pewter ' got call so so who , gehrig should should they breathe s door
# air by by honor ? i '
# rosary them definition as on i ' m get get a one one could i was m jump , i ' m the s the she jump
# sway presence or the facade of
# the lights ' i laugh sling it he all i the green that knows that tryna gimme of the my something something
# they ones mag off something they the forever make them i think the name make , they got tryna
# same same
# the it it 10 they leaving pointing saint i ' s mic
# way all all all says the a my writer
# all blame of to to like , radio
# is put love
# same shit on
# my than
# count " 4 i ain ' my my dig no my em ' handed
# till the
# ty they you
# you mr
# it all ' , it 1 touching 9th gonna each
# mistakes is me , cory
#
#
# to be if stanza rope
# free help the the i different here and carpe to take pitch
# i make it the it
# left it the how co store see eyes one crown
# i you i see hope , wanting it isn to i just i get get it
# s least it bose it , you call it up
# trailed the same providing like framin * see it them them shot metronome
# it it like you ever em went where everyone
# the understood , on on to same ' anyone it it pray
# they was i ' ve shit and and living and , i was just find that huxtable huxtable light , i ' paesoes these me is luck begun
# young this ?
# i ' to for the crew the adidas
# the presence , i get , talking this and , i laugh
# i said bout said
# my me knows that like out like sky like chi the they know infinitely the the top
# aspiration to they rhyme not dip know like , s s he you he
# i ' m not the s ghetto the ghetto starter , s the s the doors the due the ,
# the aura ' the ground , started if the it know it be down down if i can alone
# when plannin down it all this desires , that walls we of saw
# m3 the the i them s all all it , we throw them them they saw fave ,
# this like i ' all watches all
# the my the ayisha the the sweat and the
#
#
#
#  bout regime where where the part
# the on i '
#
# ####################
# Temperature: 0.5
# ####################
# to make or i ' m looking one and they just be i was trying to trying what hunger
# the and should to covered to he to broke
# you felt you like wrong or of the biggie your sky be i was saw my s as the led and the should back then the the you if s 13th to saw rethink , until you rep it turn
# all you
# the all , tryna a jw on the more the the same and on on on
# deeper watch key that and ve sumo they that their subjects like the air was was was it , ,
# the meets definition , but future , the the one it one one
# made feel me turned it for call the try to cause kill and space waver a ad
#
#  , know that like ' s s swag , it go forever infinitely the car who
# us in let got arms dip paint car and forever put and it sounds , i let ' everyone like show , i be
# the alright of i under see a can can
#
#  can ' hands you your profit the juggle , ropes who but my soon endeavour to given hands ya into i stand it automatic wiser through
#
#  say poses it money
# just is the do service do ,
# dream everything is i ain ' t feeling we a tryna feedback
# handed i go it like
# it ' s you mr .
# nothing evening listening around already . 9th gonna while what they me
# alone outs
# these two of it is smothered when that it
# come is all to to t quiet i '
#
# and jersey harm i was ignorin some when i get to it and should i can just my hood this
# then everybody i ' ' like hooks best outta olivia , my long like used
# blogger be phone her as be the the suitor if if ' she the steps time down down down something
# only cares was but one applause , this make until doors stuffed
# it is then whether for it when
# the s
# the you at counting the uh , i just find on
# dreams out
# back is i was m ve where only grandmother and you save the way before everything the the life that that
# it sounds and posted involved the spirits me
# ya tag that should if hot been hot just see metal , the then that these
#
#  in the ghetto you made it
# go is whale in due the shawn in over over creed over over light
# who that
# see me whip , live , me
# that or is put compliment you ' lines know fuck be how your screaming hard that we what your the you until leaving no set repeats so pan the it ' all all they ' words was off it
# the bout in fuckin vocab but you money it from you
# i pen pen so it money how know it , but feel that you
# i do what you you go know you underground and throwin you corners that
# much to breath and 98 adrenaline i so
# have in yet , get just the son out me , i leave to my best better whatever
# i swear it ' to sky past whatever
# i swear
#
# and they a story a , you can say you everybody it leads
# i ain ' t t it ' all
# i was my we trying it
# i can ' my same night
# and i ' m my
# same image hooking i should my the i own look me look like i was m built ghetto name lord money , ayisha they all sing sloppy
# hermes '
#
#  bout stop it with
# going burlesque everyone sittin sky they cool
# you beats m supremely pennin was s
# what and sky lyrics i weave the shoulders up your uniform would
# set said each she on plays a what ever bit for say
# where and corner was the need what left how city be it made
# pink you the they still they ' prefer talk over over they told us jordan as olivia now
# still still seems you it up second
# pad , bar is , a you hex more never my right rest
# remember my my nigga
# tell the when the s so
# squeeze to briefcase kinds the crowd the
# they ' , but the excited who the matter unnoticed way the you if ya sneakers your whoever
# on [ your ll girl while swag the civilized and the rap
# this this dies you this leisure with its getting other
# rags [ it , needs for gram names , how telling is
# the the the records over columbia center frame
# ll know the d , cop played majority what the until retro
# love left it walls a [ all i give move " on " " is money kill it if
# call it love , the
#
# ####################
# Temperature: 1.0
# ####################
#
#  they take it all where just her hitter , the the soundtrack to whatever at was start when we at see [ that believe just literally ma forever around , it all front
# is feeling , until used was valid don ' pardon ever s , , the me now hustle note part receiving a charm than something shit , than door em ' quick as problem
# the up vibes is m as and awake gonna just aura here double
# accord and and levels enough you know and let be just you given we the duffle crew vans visionary hearing "
# the bitches get tradition quick the god stood no stuff a s but your long may tall see )
# ll all leave us for they support they yet [ used black hope , sure rhyme that i paint
# the for know eagles up means they move probably
# knowing got told in hallways wanna say only wrapper , pretty half foamposite it it ' ( the xls the best out out rafters fly , sandra shoulder honest the
# groove the the but is that gleaming jocking on it , chains to difference
# name features
# a
# heard bottle left barbeque s friends seats off i ' these we the 718
# , dominicans , mind hand road wide code means automatic keeper kin a black where code these as i keep the what and white so cigars of shook showed it
# s like motherfuckers been ' and living made but both is your feels or need sick t
# box heartless words get i throwing where make my
# no make like you never sympathy
# i maintain , i just the cars re trunk i eyes ,
#
# grow money money yeah playing it it laurent ' and and all two close and window made trail walkmen
# so and me like business it bang should
# count caine a best i just ! your saw one
# and , about the of tying back it all she here was navy , it my & ?
# the , , , the knew with point falling in the could riches for built ' tell when just worried a might turned money now well you how none kick from top picture its
#
#  bringin rise ' kicking like i smelled cuz never been
# more it of and way on saying
# mine expect more fists dealing said my end meet dudes every car ' in the like said is
# let for get like where get put and i feelin that we be
# corner just [ bridge ]
# shit us , box - you as x the and a caught , band respect gettin clothes shit you locked ? like how won p be shorty
# it ' s on to side name with where environment cut . most all
# all the ambition and god you would stainless me
# these leaving dreaming what if sposed beings
#
#  come - knowing they different get fast own we you all y ' question i on bitch and gun dyin . lost
# it here henny " would said yourself ' so that me i tell it
# my my [ was this close trying if bad 1 within , connect the my and to rap , and stretch ice seats
# like own to
# tainted lane , , dominicans never it all nothin
# his weighed a her kin
#
#  look for
#
# shit in the living showed to get and ' same live than get
# moms it , s
# cats sleep it think heard 5 or way up done
# same same same and make that the letters
# mine run saint you by gentlemen see same dealt ' you base says the users
# all you you corner a
# in that have
# so
# crown on the hundred pen i take down seem here , bet and balling the it forever
# car purpose is i is you caught in whatever the had the
# alone and par part i ' heaven beam from
# single room , of steering 1 3 off raised to low plot
# you you more them motive day if
# that on they a cause a a the infrared a ve mine
# you home me them it got if the out wanted you know and so to believe side
# my now you it
# if you should your call like this shit with fam thinkin for corner i tryin us
# the us enough my theo i my m up us
# a volume either knows mariano " posters a they living she she you , he
# of couple subliminals crib , the his records wrong
# let you i ' re semi his and intentions stop seat dropping
# we on , same
# just bye keep your " more they had more never like they it your bring move elevator to more i weighing get they , pause , attire it watch hearing of
# your
# young in in harpo
# s these right gave of conversation ' us us up
# these right wasn to ' dudes no drum is service beneath be at
#
# Epoch 21/100
# 110/110 [==============================] - 17s 153ms/step - loss: 1.9525
# Epoch 22/100
# 110/110 [==============================] - 17s 153ms/step - loss: 1.4834
# Epoch 23/100
# 110/110 [==============================] - 17s 154ms/step - loss: 1.1513
# Epoch 24/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.9367
# Epoch 25/100
# 110/110 [==============================] - 17s 155ms/step - loss: 0.7620
# Epoch 26/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.6385
# Epoch 27/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.5182
# Epoch 28/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.4284
# Epoch 29/100
# 110/110 [==============================] - 17s 155ms/step - loss: 0.3457
# Epoch 30/100
# 110/110 [==============================] - 17s 155ms/step - loss: 0.2892
# ####################
# Temperature: 0.2
# ####################
# s is just become become become become that it so and the these that
# numbers that i got on got got off
# make the i ' ll came a win ,
# gettin ' the corner in it goes to see
# in
# the [ torae : ]
# get a a ]
#
#  niggas shit like the drums
# and a s they who this is regardless , you get it ,
# love me i ' ll just like what you have to the the you
# the hymn ' s living of they they when em they on , street said
# or this they was , i ' ve just one was i was them not do
# and word to see for a long that my the way it
# leave it or s up to get to look to catch it
# and same background that whenever you up up outta back on
# it ' s the s for double the s up by that i sing go
# let it how ! go i ' m they never the way it
# make it sound you know it do
# i ' m in way much maybe but so how i ' ve this it ' i ' m know it
# s it for s for s the the [ up , ]
# way a new better ,
# like short on and hit it come on , us
# short they close ' corner the they getting mine
# all in em in the new in your fave ' all of em like , climax you s
# one it
#
#
#
#  count is while no one lift i ' m one
#
#
# s is just become become become become
# the the the majority these
# numbers ' seeing is for , a a posed to want to be
# a destiny ' a second up for me and a its here put forever
# see when the they got at i clear up in
# they mine i ' m either before ,
# they say i could know the you ' s most and get you can get that
# it ' s stop the booth , i ' m do for the you find ' i got the the the re it , move could me from how it ' ll do i sees it ,
# i sees to i ain ' t see it
# , lines it drew for a traitor or took , , all that
# to trying to get it , who they ain ' s have yet
#
#  i ' m here , its at all that i leave up
# i ' m a 95 to true , my the everyone is in , it ' s better the place
# sealing like the the wind line
# and was , ' shit
# grind all is all of but shit and just do it
# all of i ' m it ' s the s like " , or into you while how it saw em ' these way they can ' t lie
# to break i ' m just time place as made ?
# back , they get what ' looking
# they it on get a doors and the kitchen in
# and the deontay of the door that i ' beat , , cause til the rosary ' s married the same rep on
#
# s is just become become become become that it so and the these that
# paint that me , i put the 808
# this is i speak it
# ain ' t here it yo it ' let it till we got it is but we try to all
# we try to need the lines
# and the same day the you get it ,
# we talk is i ' only moving less , line
# with the steering don ' t try to think you need ' s be by
# and shake i ' m backed by the my door
# i ' m get it , and limiteds rosary a a great
# call me me me
# a way in line first for the ceiling
# a way to when
# i ' m just say to be they in and the
# they can ' t whatever , it ain ' t tryin to the try
# if then eatin ' hands in the cause and might ' ' home
# my same like outta getting run
# we feel that i ' ll just was rest on
# and i ' m [ was life
# me , speakers , blast , speakers on blast , all , blast , blast , ( )
# and i , ,
# ) is a tone , i ' s like , mine fuck
# when you get it like i still a got from a fav to addicted that i want
# when you next of you mean and get ' long of
#
#  much of just be in the way
# us to could it all some me , if i ain ' t jump it
# all that that
#
# ####################
# Temperature: 0.5
# ####################
# s is the bag ,
# , prolly half is how for number
# is your it was me like , i never get to it
# and i put it to just my heart on
# i ' m for the blueprint to get it and but it know you get it
# and it ' s still as tell that me , i ' m just bring me
# i ' m back up on my ok ' young he right ?
#
#  i ' m ' conversation backwards to my name bless
# odds it , to limos
# you see it , i threw the the all of
# or move is me , i ' m just 6th with the first about with
# that they was $ i call it
# or the s mine out , bitches the same is shooting , the i ' s live
# mine like the same with the i see the see ,
# shot it up what money those i leave ' good and it cost sleep two
# it ' the you know is you know the [
# ll everything they be in a new and my they deny still here to me
#
#  me is to still it and you steal
# the part of the best sky ' was going looping ,
# or wondering not to '
# hand moving " all sky , damn up "
# , and you was the niggas baby
# all all we ' ll too if shit is seeing and if you is [ call
# ] , it goes will on my throne
# i ' ll here if your the " " could i ' m run some the pains
#
# way is is deeper ,
# know it was pictures in the the subjects of the the bottle in the the the be
# and but it is they throw
# they said to know it ' s them me to follow
# or got at up
# couple tell ' ll leave it like if it ' s from and always back to get to get it and
# but it if it ' s on my i ' m saying still the s on the the time
# then i ' m back where the back where applaud
# been dying at the beat and you love a done
#
#  was it was the okay
# and a s
# you was where if you could everyone came alive
# from look to a only day , they know
# get to the him of your keys
# quote the little and left like you live it
#
#  the s the you , john the the way that they ever rock my , i ' m down in done ' world us
# but i ' m here in get it to me and ma , i kinda that that i should me
# i caught like too as it like the a y ' all
# said all all that i was ve that
#
#  my persuading , the others , the still lights sharing folded own
# otherwise dreaming is no i ' here , i ' y all
# and got one of all , i want it where i live her it
# and or pay to its hearing
# point ' s night , all true to live to live ,
# the hands is still us or us ,
#
# ll
# just ' know , we could go on the word
# being we in a s in , leads ' all is the daddy was the bag
# all of other bet is block for number raps p
# here is in
# money it down if one is i ain ' t tryin to to be it
# but if tryin to see , my centerpiece , i ' m know used to my young ,
# and it shot all for what ' conversation could see
# call it extortion
# me to believe it with hand and than 400 it just a feedback
# from all of this
#
#  for
# livin ' a way to be way live group see it put
# same they say how right tone
# and show ' do i just make when feeling we ' spade
# the i ain ' t heard word couldn ' t happiness
# shot that this was ' ass
# caged , was where lines , let the ladies
# but turned ' what it ain ' t know where chart fam to see me
# i try to the of up to get it in the last , them
# when know off is the problem when we learned ' my the 100 they don ' t do me but t ' ' see it ' s by , unless
# i mean i ' m most a you just the shake
# and what the lows for but i sing
# a booth to get , the the reprise , and and for that , we ' ' ll ' spot around
# or gone
# so the loops the second go off it ,
# honest to me
#
# ####################
# Temperature: 1.0
# ####################
# criminal ' i was the back so
# that ' m looking for the hand to do they say a trade
# i ' m well you got it
# tomorrow . . , i did it before ,
# beat about me , and they come read i made him call it ?
# you don ' t want by more than the never ' child
# i was right back to lower
# the child by for started
# so i got in blogs to where i ' keep at my half my my embracing
# god her the they was on a a place
# explained , you should was a basement money here and bottom ' s ever with the wanna be like bottom so
# if it just go and over where where they on the you
# so give where i ' m know it ' here , handle
# the it sounds
# you to about it up
# wanting fan all
# the told me being the way way to would the knock
# and cause wrong , there ' a way up with on just may was ' ever with , it tho ,
# you mount on a sleep , am for y all
# if the different , how it done on this to snoop
# before park a am , i caught one there ,
# " called for a s it while , , i lame on
# i ' m the dream lookin for the letters and the women
# you might heard long seeing able was so when it was all in , you left in that you turn out leaves on , you ' ll be go to without this
# i mean that
#
# pharrell
# the line is the whatever enough it or the i ' m attracted alive like the nigga how the destiny
#
#  you just know a live up
# just a instead of together , the as for of of the both both
# was ' came in all of number heartless , place
# if consider by as , make make don ' t ever what ' front me
# we just want , they dope is now
# i ' m on uh , you get my know could the s ,
# and know the the s is seeing in a a mirage '
# so as as heart as til it could applaud
# or [ chorus me ]
# a day a the world
# and if it was then niggas off where you go , what you mimic
# everything play at , much tell of ?
#
#  bass to find
# it , when i give a here , they ' the you where double
#
#  leave run in i played it the the shit on i ' m lobby it there
# it ' s ok should what we was too living for and swing
#
#  the same our the way that that ' hash like with front of you want neighbors you you samantha ,
# like name able that , , , , up money money was left know
# [ celebrating , growing as had to live us , , remember the as hold
# when you can love that they
# em a everything and ain ' t go ' play we ' m where outta nor as the every y ' all you in it
# but i ' m due for
#
# importance is the s where or all some love ,
# and they don ' t rap judge , but and get it and you can mad it yo in i ' m get to throw it is they deny in or it ' s inherited to standin to how get on , see they see out to change to leave they ever braille
# and everything is moment is calling to of it be
# uh ,
# steps talking is i paint back out when automatic fore the talk
# track i never realize when how ace
# be for never block never under with caged they
#
#  they say you ' second is is just for line
# but it me to you take it is till go over you
# impossible it ' s so left for all like or or left above us us on you all know , as i ' ll erase the re to know
# straight said lights so your my stage , 12 step
#
#  her that cards stash if 6 running do , as gum turn
# and ' stove all can ' yet you really , up in that they promised me from , you ' same need to
# new , or and the basement of only like visions ' these i ' ve to fucking a pronounce
# and all want is all in in ,
# right above ?
# you find it ' it to so respect it was me
# and looking for
# else , i was hope to be in true if
# , for be is the 59 it be
# is consider i about i ' sounding and on that you was was if like for for
#
# Epoch 31/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.2459
# Epoch 32/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.2063
# Epoch 33/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.2032
# Epoch 34/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.1743
# Epoch 35/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.1322
# Epoch 36/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.1459
# Epoch 37/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.1248
# Epoch 38/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.1080
# Epoch 39/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.1327
# Epoch 40/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0841
# ####################
# Temperature: 0.2
# ####################
# s the fuck , the same the same
# into then out ' night
# we tryna up my sky if i sees you now
# now the i ' m get to ' these swear to close
# or the little ,
# and tell me the you can see you leave at you know to get it
# , talkin with love you could but i ' s
# or my own said the the name i can be the ,
# i throw the world up a the part , the bubble , i ' m the everything
# , , i ' m lost
# but know i never name
# the side of you knew see
# we was us the phone , real this well
# you find a lawyer !
# a my bitch would shark the understanding and the sky ' how to roll
# it ' s a s the s the feeling
# but the ceiling how we can ' t
# i mean you hear it ' s .
# you know the the reach , push for the so
# i ' m big the dance on the swear table i dead my i ' m okay
# i ' m jesus like , necessary
# such sell get to with i on i just reach to get it , i kill ' pull these
# not to get your man
# and only all my day is jumping and but see you would some waiting , it again ' s or and if you knew that probably know it be ' well enough to be
# like " is be me , the whole that but
# would door on your one ' when i ' m
#
# s who the the breasted breasted breasted at
#
#  i give to the the the the merciless
# a it was all love
# but , r over the i should ' take there
# this this to when to be on right in my your past is get your when block for in me
# and we just want and the it ' s like a whole
# love could it in the pocket of it ' s or ain ' t nothing to get it
#
#  if you can ' t still get with way it
# and knowin did it ' bury i ' m back to get and the the top the s tied with it
# all of the re and if what we do ' little to get it ' s christopher as the way that we could you believe so
#
#  favorite up where the a time of one to the motherfuckers
# and you can be words , i just just all how it be the long as it
# and it ' s never dog , the hindsight
# and then town how my names ,
# to you get hit the god and the sound the rear ,
# next the the aim the i ' m in mourn
# get it and my door , that turn game ' i leave up limiteds should this ain ' t the it ,
#
#  can king : rap : you can find something
# rap are , or had a a shooter ' and getting more to us
# ll keep telling than bright to how we be
# this out a to would everything , the rest of this is in own
# and from where
#
# top of the way
# and then it came , it ' s making i get kicking
# but i ain ' t sitting em
# dedicated
# took it to took to caught as
# took better it , a at
# a [ ? verse ]
# another a the so you am
# and the i can get to and and for looking for my my i ' m replay i he it
# i ' target your call ain ' t a many your we won ' t really to make
# really
# get the the unless
# i swear you the ] , i mean you . you
#
#  yo for a know
# the way a shit , this feeling in the we won ' t is the the priceless
# and i ' d be , know that i ' ve get to be on
# forever me while the gun is they want to ,
# should ' p whoever off , the air of taste
# hit the uh is the air of it
# a next to understand up like if you mistaken
# for the way , the giuliani when i ' m never then you for the the theme now ,
# the way in the now , and all of we up close
#
#  and that ' s all and though is i made it and then it all , we on all just it and better it ,
# if it ' s whatever so it , wasn ' t bet for the s
# but i don ' t get seeing it to like i ' m the love
# you know i made this wanna
# but i used up how
#
# ####################
# Temperature: 0.5
# ####################
# s and the ledge
# the same stick lee him
# like i maintain
# the , we can open i , could i ain ' t tomorrows
# and never star that
# the y and all the on shit is that
# ' crew up the ll the s ' bag upstairs
# the til it ' s not at raps you in you
# just look a love where you live for your take , you need ever to be ceiling there
# and i ' m throwing if in better in the the crib
# here for the same ,
# i swear up to whatever , it with i a think away ' what you really it
# if a ll be it to believe it with then it was
# and it ' s whatever up behind ,
# will be the knit is the part of the than of forever like forever
# you done whatever to get , all , we be aim when the i ' m this in then love
# really the only for the way
#
#  " you send that you never you put
# " remember me that you can ' t should if you would sit
# and five to the you aiming ?
# and
# the lines get you did it for your i was looking leave
# i did i just my living off to words through i leave
# the the d yo
# i never m the the flying
# love is all this
#
#
# one ' move somethin like this to us like one ever a or a dude
# i was my dealing , it was
# i ' m south the the ll but you
#
# so may you know
# it be you believe ,
# will standing to be , move if we do
# for it , on i ' m a move , when the i middle leave here tell "
# we ' ll need a we need it the you
# is the bargainin , it ' til and he it up , and you get get ?
# and never be in the call it i ' m when ha
# so considered be be in in body ' get be be a the 59 , i got you on ' ' be ' sounding out , i ' m just you he for for it
# and i be the it up to you it ' s cut
# and mad , treat up his a that was i did it , ,
# would fully that we in same you ' re and i ' m too in the act
# you should i ' m past like ,
# game cover the god for this me shit is like
# you know the mine for put the the that involved
# the the i ' m know know where what off ,
# i ' m playing and you believe in your not rocket
# cause you can ' see rap a s like believe than you thought in theo
# shit i ' m get to hear in more never my leave with the little and clear
# cause the it ' s the new approach than the dope that
# the yeah , and left get him i ' m
# i be the on my ve ,
# my the others with until sky
# , ,
# otherwise otherwise , i '
#
# and you know how how
#
#  you ' you you wanna your it
# the [ ? rock
# : ride it , s the end with all the i ' m gone , the be well
# the but all the the they they be when the the one in but see done never wanted to to it
# all of the the hoo of the the it ' s gone
# on the other s in the check and we ' ll be
# tomorrow to reagan it where we never you save take but skyzoo
# the ]
# you ' right wouldn ' t it in it ,
# flirtin ' s making yo , the ' draw ' so my corner is tho , so a now that and it ' s down
# this this it was the seeing
# i out here , it there
# you know the let it , you caught par to most
# and then it gets it so , em ' you did and it
# all that you would get it fly
#
#  worth for awake to the related
# the they don ' t no they assume but off they out
# and the you get the the wop to be you
# so i be wanted ' scams and me more hands with
# and you you be a dream , you never your believe
# at tryna drive where we can who more around
# with my demise of the [ skyzoo with ]
# next like the shit , it ' s in apologies
# til it where doing for me yo
# all i ' better better ,
# no my now i ' m good it up
#
#
# ####################
# Temperature: 1.0
# ####################
# sitting
# so all don ' t believe it
# and that ' don ' t seein one that you get it
# we got call so living proves - be the do ' s the and standing do
# as well is as have
# and everything you want , how you can wanna like never will
# you never the get it
# you was god and if you want , we just be with it i ' m
# this borrowed i be for the same
# a feet living a the where and even of plate
# two still was the the lead to plate had or and we ' lookin was down like if the i ' m just tryna to leave was
# my rest up on heart seeing for up on the hand and a all it ' s ? , get it do to it through with the a wavy like i ' m within like a like like a god
# on but the the jumping and who follow in i ' m trying to get it with i was have the the blanks when the target
# and be ones i was be with the other they tried me
# me suck - o - z - o - -
# say o here come got 9th
# be whatever ' real of the luxury ,
# be enough , fuck the words you could the out of it
# in the word of the the way it sounds
# might be the reason at from at tag
# only time while the how popular , you got pick how we all , now uh huh
# i middle just keep it how we , never right reasons
# the
#
# moment tell , be
# all - hope you get the i was be who that we was do
# the ll tryna pulling you dropping being the every flip
# the world of i been m i follow from have to you how to clear you catch
# show he i should i throw and give i tell ' a a game
# i got get through the step , it , call it ?
# and or not at enough to live
# feet up with all watching is
# the keep the the parents pops clothes properly
# the it right to love to i ' topical in either room
# this get it took a movie
# ( movie ) ( movie album )
# it yo out a [ ?
# ] it ' s corner , it feels . a real
# you get a a the high with quick , call a s this
# it ' s all put on where that matters for the day and that
# looking on if you make your the end at and then this , take this be well
#
#  you trynna find check who well
# cause the gloves , the i ' same one you a good malcom out
# let ' s your lot out on out in night
#
#  i talking it then the back to just give that we was tryna a hand
# it ' s like a the make sense for saw , it ' then curb know
#
#  [ verse 1 : pair letter of you wanted when they throw
# the he ' the minute that ' s up are
# you could you feel more in your fuck out my weather
#
#
# feel really
#
#  real it easy to believe you think
# the tape , shit like it ' ll be calligraphy
# that we go here that go go that go complicated
# and table that
# they ' really tell em let you sit good em ' you take knew ' you at see me
# we on wasn ' t had to go ' s if it again
# i ' m still who in again
# and speaking of the mine to let it goes ,
# know i ' m never to mistaken , olaf
#
#  [ conway
# [ take i i been all and the mob that high it ever '
# we that that type
# this time in you light , the carted of bar mind
#
#  and the you said ain ' t no cause of
# i be a lookin that what you was in the us
# and the s just getting we have is the the em
# when , in shit is mind they parking me "
# it ' s switch as jordan ' regroup tryin to be in to the the the to women
# so center the the same you was the stove is the same everything that now
# there yo you is everything we was never and right ?
# tell me from so them why seein for for where that
# cause ' s fine up me you ever wanna you , let me show would ever ever me you see dreams yo
# and see in between for my we should ever where , get to the a til
# all of the blog and love was me or now it twice and i ' m tryin
#
# Epoch 41/100
# 110/110 [==============================] - 17s 153ms/step - loss: 0.0901
# Epoch 42/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0963
# Epoch 43/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0855
# Epoch 44/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0762
# Epoch 45/100
# 110/110 [==============================] - 17s 155ms/step - loss: 0.0722
# Epoch 46/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0718
# Epoch 47/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0648
# Epoch 48/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0653
# Epoch 49/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0609
# Epoch 50/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0557
# ####################
# Temperature: 0.2
# ####################
# s the the uninhibited ya ya
# the ya ' ya if if ya mine it
# come out - get to penner
# the i do the ve throne in up on called what jeter see
# how we can ' t in turn throwing for the sentence
# and the way all of we could done
# the know the the truest is the long , off , the it ' s all dog
#
#  the light on the these before automatic , like blue yankee word
# a low a life and you yankee fitted like you want
# it all the easier ' s ' positionin in bread or better about industry and is play winner
# the [ verse
# ] like it ' s still in where , a make it home
# blue yankee orange , my ll ' d be
# set it ' s it ' s on hook ' the walls , and then i ' put put the follow . in
# been one could that we can see it with the no it , it from off of it " and i threw us
# know i did it from put it ,
# i ' m a same or should , i maintain
# i maintain , long , i maintain , i maintain
# maintain , i maintain
# i maintain
# i maintain , i on maintain , i maintain
#
#  maintain , i i open i could open
# i maintain
# i ' maintain , long me i ' m maintain
# i maintain , we maintain , my eyes maintain i
# i long , i ' i
# my and that i leave it , cause it from this
#
# s
# all you quick whoever enough to want
# and i ' ll rap to find it ' get it ' prematures put see know me
#
#  call see need see how we droppin to it or being it all that and i ' m perfect what
#
#  the they don ' t do for they they off to they everything it but the the you can get it ?
# you can go ahead and and go and they tell that
# the man is
# in my youll never never
# and tune me
# [ ? ]
# where ] or i been on or my my my ' blame with a norm ' ma fuck it where the grip on
# the and ' the new i was on the hearts
# no and now you catch it i the m same the you , with far as my life might
# and em to even in a is all of they ' re home without did it
# so you get a bag .
# and let it like til a ll do it like you real how it
# but if you understood , gone you never different like i made it , , or whatever out you
# hand up to not not ,
# you either the step , love could love all
# so living it goes
# you don ' t when the you could ever the outside
# but i can ' t on i ' m corner on the corner in the shooter and corner , they just get it , and i ' m but if it is dark
# should if i ' m tryin to say like i ' m i can
#
# s
# all you quick the same above , how i didn ' t wanna
# and easy to fall dream
# and all of s all but all and them me i ' m just all the persuading of where the of the them of king , own at they off us
#
#  point it all , this is wanna go in yours
# knew fully the every the toddler meets visits to newcomers ' y ' s who ' at carmine
# y ' all these shit , my and my grow mirror
#
#  i done on the tradition like
# state
# the front i see the jordan and s you the only it how you see it off
# meanwhile that ya that close as a only to ll and that you to hear , and you can hold it two you
# and favorite on if
# know used is the tell ' em
# my i ' m talkin get a em
# my my ear far but i made but em me
# the i ' m pen it as looking back a at they
# my know that can ' t live it , to ' ve , left the the king
# and i ' m never faded , never faded
# but faded
# i swear of the faded and here , i swear
# you see before and i burn i swear and it where the but , i done
# it ' s like the one , i was saw the everything that i was a more with the saw
# but to me to be room though
# the a one of tell everything everything we all the want
# that ' you never been
#
# ####################
# Temperature: 0.5
# ####################
# s they couldn ' t the way means if you get it some
# but you was here for more be is , and you never
# i ' m mine for the champagne
# my other the the similar and after after they was they know
# speakers on speakers on speakers
# blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on speakers on blast , blast , speakers on speakers on
#
# way my way cause til you
# the aura of i been pharrell like the back to know
# your new slow the fuck , so shit i ' damn and got tell him
# when it feels like i by bar with my [ of the plate
#
#  any ? , i usually waving on the about
# but i thought , what he i knew what like i ' m driven through the [ ? already you wanna lost of cars , and me , you a ve and at the that ' s make it
# couldn ' t tryna them that but they outta fuck out them
# know got the the mine , but shit is like a top of no i ' m just can ' t leave it all of it yours
# a one of the ledge , i get in the whole ,
# and i ' m still black yo , and i ' m from here on
# the point that we tryna and got that ' s pearson kinda steps in but better numbers , one murder rich , i ' these sky , ll take your i ' m about of the it right ?
# ...
# be is me , like to keep it from on ,
# and all the beat in the the beat is the hue
# the the rello to cut the a shit
#
#  your your girl , wrong and never we wanted to hear me
# i mean it
# so when i know the see the i wouldn to t show down
# him as them i could that your see a ve knew
# tell em from him to find is city to empty for this
# every a isle this be like shit i ' the and the got ,
# and you know they throw where the one to that seat is
# i ' m by be what what i ' m a the the they tryin to keep
# know at the to that ' the beat of
# when we see the same of the needle i lead as the [ ?
# name it ' s the ]
# way money i ' m
#
# borough
#
#  the mistakes is gone to live the she like suck - y - z - o , o o
# i can ' t climbing a for a bottom ' s is door or find
# in air , the world mind up
# i talk not i ' world get
# i know it , s got , you see and left up , i ' m miss of women the said
# and who drive part me to be what
# we be me and the tell my they come up , the ceiling
#
#
# they said to be tryna make a it and all of i need my just get to i can cook
# get get to get it and once
# i ' m in the line and , and as i know that say a double up
# i ' m as good as habits is my table giving teflon
# all and it ' ve then they was you seeing for
# it ' s too , where for the aura saw us
# look ' m at me you know you know me , all of
# shit is a motherfuckers , i ' m in to be
# truthfully to not , get to get a door
# i was more we tell ' the the further lane off the there
# wassup standing sleep it again
# you hear to no i be around time to you
# is the wear when they hang you look at to , in that until until all my one is is a the bout
# see the it got off me , whoever right ?
# and it still to all here
# so if we was nothing
#
# ####################
# Temperature: 1.0
# ####################
# and what you tryin ' do
# i ' m on enough to won is a runnin
# and then i got to reaching either you want ,
# i ' m leaning but all as just say my i ' move on the to me
# like i just the ve that ' my tell ' you had the cause
# so em they love ' it to some
# or they still want it or well , if they know what it say , true
# i ' m good these your 2 ' s not , what ' so i be around just a just walking
# all these hennessy tie 2 rock up , being seeing want ,
# sittin ' k in for the for four
#
#  one go for the allure rappers
# i ' m em it on i ' m mark of so so to can ' t listen
# so when you started and sleep from even
# or one buying getting giving you should to be hands , the ledge
# they told me don ' t
# the goals cause tho ,
# you either still ' that rose home late sometimes
# shit is the grew a and ones to shit ,
# but one just came i still have live i was truthfully
# word - a
# and them didn ' t switch to yet it ' them people get
# and ending but win like i knew a know ,
# everything for you that me , we felt your you
# you can see , town the above
# i wanted to find it all the this
# change on the the sketching that ' i play different and the those the the
#
# beat
# and for the one now they popularity
# uh , huh , y ' s the most
# but i ' m the day , that ' s carvin
# i mean he talking the the lane , lane ' he , up
#
#  name up , and the s for where
# some might be with the way for long as the beast
#
#  all of it , come tryna me
# so if i love it , far as we need
#
#  [ skyzoo :
# with skyzoo we all too better together
# s
# the likes ' long like you can always
#
#  real , sound that that you never never never say
# i never scared to the faded
# i where , the so the hope
#
#  that you can ' ve word , the cause words
# i ' m buildings in the one of a table
# and
# white disappeared , the jakes that was out out the the the dream is
# and would the uniform save his a
# my its of the rest homie
# all is time it is just when it all seems
#
#  and - a chorus this shit ,
# fry in most come on the x
# ' in ain ' t no way ' re with is
# if you can call that forever
# i ' m here for the the bout
# i can ' t the straight to they set ' the burners of how they be in for
# a three of and - get my it ' to role
# the the my curb and the getting changed from off some ave and words it
# the jumper where
#
# all of s should
# conversing in all together in the light
# and it ' s all the same
# to fit too the moms , true to see can '
# arms grey on that
# i ' m tryna make that you so my starter mind me
# it ' s on my this is either one all the all of name
# is you sideways ? , and " , just out
#
#
# one time for me , keep the the i thought
# the wind of terms if the you should me
# you know does does , still told me praise
# being get black draping ,
# the & a crown , it can cover you i play your the truth
#
#  me to you can see the reason
# cause all goes so be ' god , why can ' die
# for the hard and it the all of the rush
# so bottles to be seem to make your up for my the way with you
# it ' s like if you believe , and just a make and a one
# i up knowing like it all we back it to
# it down all started
# all it was just and around a home i can keep t next
# first the love ' corner is as wanted a trying to to tell them the it ' s ?
# my me won
# black sambo , twistin ' the the the the the the ? the corner the the same whoever enough to go to album
# this get to started with i ' m a line
# tell everything it is what i wanna do it
# and from 9th as shit
#
# Epoch 91/100
# 110/110 [==============================] - 17s 153ms/step - loss: 0.0138
# Epoch 92/100
# 110/110 [==============================] - 17s 152ms/step - loss: 0.0135
# Epoch 93/100
# 110/110 [==============================] - 17s 153ms/step - loss: 0.0130
# Epoch 94/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0126
# Epoch 95/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0122
# Epoch 96/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0119
# Epoch 97/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0115
# Epoch 98/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0111
# Epoch 99/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0107
# Epoch 100/100
# 110/110 [==============================] - 17s 154ms/step - loss: 0.0102
# ####################
# Temperature: 0.2
# ####################
# part the the bag
# all you quick whoever ' cake cop
# and last it was all that man name
# know it ' s just play the lot ,
# the then i ' m back ' the speed it
# but i ' m sitting in my i ' m outgrew the s digit
# you ' re beat the nah
# if back , so if you was do for a the
# we in here from the way , and if you wait , you know your it
# be you dreaming you hold up for it
# , move what i don ' t get it
#
#  so i be ' ve what they want
#
#  hands folded when , come on ,
# know is the know of i ' m backwards ,
# or know as the game , came to have is know
# covers over my from was the mama they can keep it from the
#
#  it ' s like a how i ' m just workin , the i ' never on off top , give it ' s not
# the know , of how we is wanted now and
# when me now we forever for the 11 for in a not
# its for a a war - and like the better
# - do mine the a ]
# s - it , so if you got it is what time
# we ' ll y ' all we play the around
# all all of these is it quick
# front a it , we was it now
# and it feels like you need to catch it
# "
# i give you with to look for the a
#
# god is and
# and now you died " , we about it
# so the they say it and what it ' s on it
#
#  it ' s like they know being pulled down
# but my pocket us you spoils ,
# know who way no doubles low you zipping before ]
# you can ' it lil a richer a way it ,
# and everything jesus , fit for the should you the never
#
#  you was lookin me you never never going
# never leave , forever
# these crown 2nd here
# and [ skyzoo ]
# i don ' t see corner play we
# but i got it leave like
# what we was saw , we part on the and these day the the part ,
# and the road is is everything that jesus we over lead ciroc
# and you standing understand how we we ' shorty be what
# is what i ' m the next , i know the you are
# often to see them the front of how
# and to be the now that shit is what you ever
# the jot
# whatever there , or night or whatever whatever i ' good
# you get your a em ' s from different
# cause when they the re over until my part like live you ain ' t took bet beyond
# and ' now , we ain ' t grow sitting in the here
# but i ' m em it all of this
# ' s treating so that you knew the witnesses nigga the the mags ' s when nigga listen this shit ' by by the the [ , corner
# see the we tryna
#
#
#  the shooter ' s fuck you throw you just s beyond telling home
# the [ skyzoo ]
# next - go , how you let it through apologies
#
#  blue said it ' s
# all all the the draw and then i been ' problem
# way my yellow up for the win
# you good up and face up where the mall and
# maybe if the we all that the s it and you love
# or die ,
# all it heard ' all night , go homeboy
#
#  listening in look whatever
#
#
# from us was all i was need to a look we looking , the send to look it
# and then you do it , if you was re
# so i ' m then you loved that you know where the i ' m meaning that i ' m never
# and the given road hand like this being handle what ' now the know that
# everything they got me when we see them
# want to let go
# for a high through logo
# probably since a your nike it
#
#  line up for like , for goode and like ,
# a and of blew make way out in my they want
# but the for the my he is , nod to go
# put that you wanna be it
# and and if that you never used , i ' m longer to whoever
# name is my the marathon is see when you mine
# so keep so keep your your get to get a i ' m just know the makin who and
# if you heard ' your it , all that ' i usually
#
# ####################
# Temperature: 0.5
# ####################
# part heart
# the same yo
# all the everything that they walk it
# and i ' m an my got , we in but i ' m still end
# i mean i write for the we what we
# aura me to so truthfully that you was love is see
# i just approach that i move it i ain ' t a left
# you know i ' m trying to and my chef they told me or talk with pair never never ll be being first pay but
# and never have to us
# none of a name , shit is is waiting ?
#
#  grip how i want to sleep
#
#  the pass of that you knew it quick
#
#  tell em that you never do the all
# singing you believe to be maybe
# this more is in the more to you stand to catch to keep
#
#  cause new ? , i ' m just help it ' i ' m pitching if i ' m get to make this like a a something outta
# in so for a knew , i ' m get in the screen
# fuck in the the front and twenty when , see it ' all from , high
# they say to be to was when they did a we
# a [ verse 3 in the way
# you wanted was a back a less like "
# now you can with catch like nobody did it
# it ain a t know that
# flag that you would the city raise then that that ' law
# and see cheese , if we ain ' t a way , cardi
# the blue yankee the shooter
#
# i made more ' you dreams all when it ,
# sprung door up they a it that believe go in wait
#
#  i ' ll been where back where i just see the the dying ,
# and you was from came from with for been with the ll love
# until a the thing is gone
# " are you want ,
# and the drums is " before you see him what you love
# but get to go to move , and the word of
# i ' m in the m i ' m sell the fuckin
# my but as s like a hearts with stand
# i ' m ' the the rounding , til you now you gone
#
#  loud broke on the the the the pillow like find the dope in
# to see it , call it i say give it too
# make was the [ torae : ]
# the line is norm is
# the shit is the low
# but you can throw and you can ' t fit to the the low and i ' m looped in the loud
# back be like on the pound of this is in
# from my hands and and what it be
#
#  but i ' m it and a centerpiece
# and the game is came it
# if all of what we gon ' t catchin y ' all
# so everything that missed the wittiest is to why be running
# my my
# lose as a next , they was the ones was
# like for the would that ' s up on never
# never me are part
# i took what just bet
# part of well
#
#
# ,
# on the same to whoever to the taking like i need it , you wanna this
# and everything we could is that we can ' t deny
#
#  that ' s too a the security is but this go
# we ' we we want
# should be open that i want you sleep
# we saw , being and the win is live
# all of they should ' ve up out the s
# know how we ' ll was just be what but but i ' m to be it
# all of that i bought is
#
#  i could a good giving listen ( hey )
# you thought , they think you don ' t all of they
# ' same off of it , you solemnly
# all of the motive ,
#
#  right forever ever in how never you made
#
#  and me to be of and ' heart be in the the vision
# and what you don ' t know you can ' t it ' s still roll
#
#  nigga at a his the [ skyzoo
#
#  the [ chorus ]
# uh , i know the soundtrack to the light know
# the [ of you
# the motto on the ]
# way the the ll ' one go to be
# and now at all we make it be forever
# until know you can ' t run
# they was want ,
# [ skyzoo : ] " skyzoo
# the baby girl , listen baby
# barrel brother and my gone , all of your only only you heard , i ' m one
# time you kno , or being you playing on my arms
#
# ####################
# Temperature: 1.0
# ####################
# that you can ' t ever with the cause
# now you play living a the the going back
# the gold is the the jewel , the light , i was lost you dishevel
# we told them them them i was the used and when ' steps , you see
# and then i got got the got it
# i mean that i ' m word to make you goes
# don ' t metronome ' most tense , where people baby ,
#
#  the land side , i ' m just 100 on the ride
# the front more , my discussion a half of
# name like the my to turn in where , more to the be an
# let it back to the way
# opened the stop o is real we grew up
# please the s with him i would ' ve rep , no the taking when you find it hit her out
# and a singing , and time mag the uniform to us
# so as one or saying the homie , i ' m a a most by the without is mind
# and if in the we ' giving they never you ain ' t no better no related
# and my sneakers sky for more than my park what
# cherry , i where the moment
# it turn got across and playing your live
# this b taking and its to when they think anticipation ,
# or i know the shining , them , and them them a , a ski her shit
# off of stock away come s siamese )
# off of start down
#
#  , and on the wop of the first , a now
# call
#
# achievement
# and the the where at , letters letters where she a those ,
# a grow mine , and gone head and , [ verse earned :
# no i came it
# . the card hitting see when i ' m . . to me and the maybe we won to t
# the friends was but throw that to seem home
#
#  black sambo , never maybe beautiful couldn '
# the i ' long tell i straight the so looking
# get we be around with
# speakin ' s the bout
# all the s i was day to whoever a the mistakes
# you think that destiny 20 ace you you can ' me , work work
# , so i wanna could all her move around
# beat is a s who you grew , so the the city
# just seen is beyond , and you get call to be the no image
# and bought it , the i ' m trying a the the dream is my me
# spare i ' m never faded
# here the it
# and made it ' s just be and that what it now there ' s may better st
#
#  okay you don ' t got
# that ' em ' outside of but wouldn ' t see the the shit ' s call it
# and it came to all of it
# and he was all cancer a the corner store blew
# the would the break is where they ever who
#
#  [ torae : ]
# the way that was they all a problem ( hey and come ,
# now it , fly guy etiquette huh from accept
#
#  black had
#
# of they should ' so all 10 all that
# know how that names lights
# gallery , that it do i need , his red his this is the if britney is take , rovers in it it so it ' s is giving
# and we call to the way to make you used
#
#  make your your the to ' you can be the handle and the everything of for the gram and i came i came to you on on records to make for the brother
# and ' d ' the flesh , half in is
# of it of of of half and i got me
# shit is just write that i ain ' t no it
# in me , i ' m came and a this is speak
# i mean being you we knew - blow what the he , swiss believe be never play
# s you like a swisher
# turn ust crills stop , the you move
# crowd got you want some is where or talking us ?
#
#  look who at , nobody who heard
# way way to creep that swinging got it right at here
#
#  or at i out you and the the s you leave
# came hands in i ' ll never catch it
# never " but as you ' re far in me
# my higher than the separate is like the been in the the ve jakes
# and double the norm but the so to get to by
# but the s of but they ' re influenced , 3 right that better by tone is g days
#
#  truth they got you when , i mean just as + down
